# %%
from VJAnalyzer import *

# %%
contest1 = get_contest("Contest1.html")
contest2 = get_contest("Contest2.html")
contest3 = get_contest("Contest3.html")

# %%
verbal_stats([contest1, contest2], True, "myVerbalStats")
# Out:
# Verbal Stats 1
#
# Accpeted submissions: 2702
# Total submissions: 4269
# Percentage of accpeted submissions: 63.3%
# Height percentage of accpeted submissions: Problem K with 89.4%
# Lowest percentage of accpeted submissions: Problem V with 32.1%
# Verbal Stats 2
#
# Accpeted submissions: 860
# Total submissions: 1264
# Percentage of accpeted submissions: 68.0%
# Height percentage of accpeted submissions: Problem O with 100.0%
# Lowest percentage of accpeted submissions: Problem A with 26.3%

# %%
graph_scores_histogram([contest1, contest3])

# %%
graph_submissions_per_hour([contest1, contest3], True, "time series")

# %%
graph_submissions_per_problem([contest2])

# %%
verbal_stats([contest2])
# Out:
# Verbal Stats 1
#
# Accpeted submissions: 860
# Total submissions: 1264
# Percentage of accpeted submissions: 68.0%
# Height percentage of accpeted submissions: Problem O with 100.0%
# Lowest percentage of accpeted submissions: Problem A with 26.3%
